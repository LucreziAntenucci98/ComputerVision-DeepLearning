# %%
import os
import shutil

folder1 = r'/content/drive/MyDrive/ProgettoCV&DL/test/tirocinioclosed_eye'
folder2 = r'/content/drive/MyDrive/ProgettoCV&DL/test/tirocinioopen_eye'
folder3 = r'/content/drive/MyDrive/ProgettoCV&DL/trim_images/TRIMclosed_eye'
folder4 = r'/content/drive/MyDrive/ProgettoCV&DL/trim_images/TRIMopen_eye'
folder5 = r'/content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye'
folder6 = r'/content/drive/MyDrive/ProgettoCV&DL/MRL/opened_eye'


'''

# iterate all files from a directory

for file_name in os.listdir(folder1):
    # Construct old file name
    source = folder1 + "/" + file_name
    # where to copy file
    destination = folder5 + "/" + file_name
    # Copying the file
    shutil.copyfile(source, destination)


for file_name in os.listdir(folder3):
    # Construct old file name
    source = folder3 + "/" + file_name
    # where to copy file
    destination = folder5 + "/" + file_name
    # Copying the file
    shutil.copyfile(source, destination)

for file_name in os.listdir(folder2):
    # Construct old file name
    source = folder2 + "/" + file_name
    # where to copy file
    destination = folder6 + "/" + file_name
    # Copying the file
    shutil.copyfile(source, destination)

for file_name in os.listdir(folder4):
    # Construct old file name
    source = folder4 + "/" + file_name
    # where to copy file
    destination = folder6 + "/" + file_name
    # Copying the file
    shutil.copyfile(source, destination)


print('All Files Copied')
'''


count = 1


# iterate all files from a directory
for file_name in os.listdir(folder5):
    # Construct old file name
    source = folder5 + "/" + file_name

    # Adding the count to the new file name and extension

    destination = folder5 + "/" + "closed_eye" + str(count) + ".png"
    # Renaming the file
    os.rename(source, destination)
    count += 1
print('All Files Renamed')
print('New Names are')
# verify the result
res = os.listdir(folder5)
print(res)

count = 1

# iterate all files from a directory
for file_name in os.listdir(folder6):
    # Construct old file name
    source = folder6 + "/" + file_name

    # Adding the count to the new file name and extension

    destination = folder6 + "/" + "opened_eye" + str(count) + ".png"
    # Renaming the file
    os.rename(source, destination)
    count += 1
print('All Files Renamed')

print('New Names are')
# verify the result
res = os.listdir(folder6)
print(res)
# Out:
# All Files Renamed
# New Names are
# ...

# %%
# !zip -r '/content/drive/MyDrive/ProgettoCV&DL/MRL/closed1_eye' '/content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye'
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0013_01635_0_0_0_0_0_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0012_00191_0_0_0_0_1_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0012_03359_0_1_0_0_0_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0017_00097_1_0_0_0_1_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0012_00252_0_0_0_0_0_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0013_02890_0_1_0_0_0_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0017_00123_1_0_0_0_1_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0013_00723_0_0_0_0_0_01.png (stored 0%)
#   adding: content/drive/MyDrive/ProgettoCV&DL/MRL/closed_eye/s0013_01367_0_0_0_0_0_01.png (stored 0%)
# ...
